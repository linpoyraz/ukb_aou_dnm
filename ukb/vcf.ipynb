# %%
for chr in {1..20} 22
do
    grep -v '#' "/mnt/project/DNA repair genes/PGEN/ukb_chr${chr}.pvar" | awk '{print $1, $2, $4, $5}' > "ukb_chr${chr}.vcf"
done

# %%
dx upload *.vcf --path='DNA repair genes/PGEN/'
